# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %%
#display cities
cities
# Out:
# ['nikolskoye',
#  'nizhneyansk',
#  'karaul',
#  'coos bay',
#  'katsuura',
#  'vaitupu',
#  'port elizabeth',
#  'geraldton',
#  'thompson',
#  'asnaes',
#  'hilo',
#  'taolanaro',
#  'mayumba',
#  'luanda',
#  'aklavik',
#  'tsihombe',
#  'prince rupert',
#  'bluff',
#  'namibe',
#  'rikitea',
#  'barrow',
#  'jamestown',
#  'nangomba',
#  'souillac',
#  'chokurdakh',
#  'atuona',
#  'nome',
#  'kutum',
#  'harper',
#  'vao',
#  'longyearbyen',
#  'peto',
#  'paamiut',
#  'prainha',
#  'hobart',
#  'ahipara',
#  'tuensang',
#  'flin flon',
#  'illoqqortoormiut',
#  'bargarh',
#  'aransas pass',
#  'nogliki',
#  'bredasdorp',
#  'copiapo',
#  'castro',
#  'san lorenzo de el escorial',
#  'ulladulla',
#  'ushuaia',
#  'tiksi',
#  'port alfred',
#  'saskylakh',
#  'ardesen',
#  'mys shmidta',
#  'saint-philippe',
#  'busselton',
#  'khatanga',
#  'punta arenas',
#  'visnes',
#  'bethel',
#  'jovellar',
#  'tuktoyaktuk',
#  'torbay',
#  'tessalit',
#  'dikson',
#  'meulaboh',
#  'belaya gora',
#  'mataura',
#  'bayir',
#  'new norfolk',
#  'hithadhoo',
#  'half moon bay',
#  'ribeira grande',
#  'kudahuvadhoo',
#  'dhadar',
#  'kut chap',
#  'klaksvik',
#  'albany',
#  'provideniya',
#  'sept-iles',
#  'kashi',
#  'hienghene',
#  'honiara',
#  'ayr',
#  'upernavik',
#  'qaanaaq',
#  'spydeberg',
#  'beringovskiy',
#  'ancud',
#  'zhigansk',
#  'adrar',
#  'rabo de peixe',
#  'maniwaki',
#  'avarua',
#  'lebu',
#  'kulhudhuffushi',
#  'nantucket',
#  'bonavista',
#  'lokosovo',
#  'saint-tite',
#  'sao joao da barra',
#  'yomitan',
#  'pedernales',
#  'mar del plata',
#  'fortuna',
#  'puerto ayora',
#  'broome',
#  'belushya guba',
#  'inirida',
#  'santa isabel',
#  'carauari',
#  'christchurch',
#  'san quintin',
#  'barentsburg',
#  'butaritari',
#  'chimoio',
#  'daru',
#  'praia',
#  'kaitangata',
#  'georgetown',
#  'mahebourg',
#  'haines junction',
#  'cape town',
#  'cordoba',
#  'lata',
#  'pathein',
#  'yakeshi',
#  'leo',
#  'sentyabrskiy',
#  'vardo',
#  'yaan',
#  'kloulklubed',
#  'victoria',
#  'san patricio',
#  'labutta',
#  'tondon',
#  'oktyabrskiy',
#  'yongchang',
#  'faanui',
#  'gorontalo',
#  'arraial do cabo',
#  'east london',
#  'saint-joseph',
#  'clyde river',
#  'mastic beach',
#  'attawapiskat',
#  'alofi',
#  'tokur',
#  'carnarvon',
#  'cidreira',
#  'bandarbeyla',
#  'puyang',
#  'svetlyy',
#  'pevek',
#  'iquitos',
#  'keti bandar',
#  'tumannyy',
#  'luderitz',
#  'vaini',
#  'te anau',
#  'alotau',
#  'severo-kurilsk',
#  'sioux lookout',
#  'nhulunbuy',
#  'marzuq',
#  'da lat',
#  'sroda wielkopolska',
#  'fonte boa',
#  'puerto narino',
#  'kroya',
#  'kodiak',
#  'vila franca do campo',
#  'kavieng',
#  'bonito',
#  'barra do garcas',
#  'sao filipe',
#  'berlevag',
#  'dibaya',
#  'kapaa',
#  'san lawrenz',
#  'puerto escondido',
#  'hun',
#  'assiniboia',
#  'micheweni',
#  'karkaralinsk',
#  'lodingen',
#  'awjilah',
#  'constitucion',
#  'batagay-alyta',
#  'mackenzie',
#  'piacabucu',
#  'acaponeta',
#  'mezen',
#  'komsomolskiy',
#  'iberia',
#  'guaratinga',
#  'dunedin',
#  'khandyga',
#  'sobolevo',
#  'hermanus',
#  'laguna',
#  'simao',
#  'balintore',
#  'samusu',
#  'belyy yar',
#  'akureyri',
#  'tuatapere',
#  'sembe',
#  'hasaki',
#  'vostok',
#  'comodoro rivadavia',
#  'palmer',
#  'nykobing',
#  'baykit',
#  'ewa beach',
#  'poum',
#  'rungata',
#  'grand river south east',
#  'dalbandin',
#  'papasquiaro',
#  'shingu',
#  'maragogi',
#  'kampong chhnang',
#  'faya',
#  'bukama',
#  'saldanha',
#  'umzimvubu',
#  'nuuk',
#  'yellowknife',
#  'bambous virieux',
#  'mitzic',
#  'det udom',
#  'quatre cocos',
#  'kirakira',
#  'flinders',
#  'asau',
#  'staryy nadym',
#  'esperance',
#  'ikole',
#  'araouane',
#  'laguna de perlas',
#  'ngong',
#  'praia da vitoria',
#  'abu samrah',
#  'tiznit',
#  'salalah',
#  'quiruvilca',
#  'jacareacanga',
#  'naryan-mar',
#  'niquero',
#  'muisne',
#  'tasiilaq',
#  'nanortalik',
#  'usinsk',
#  'artesia',
#  'lolua',
#  'port macquarie',
#  'chenghai',
#  'saryshagan',
#  'talnakh',
#  'palotina',
#  'birin',
#  'ilulissat',
#  'la mana',
#  'aflu',
#  'kenai',
#  'ugoofaaru',
#  'bilecik',
#  'sorkjosen',
#  'zyryanka',
#  'kandrian',
#  'avera',
#  'chuy',
#  'gat',
#  'lewisporte',
#  'estevan',
#  'westport',
#  'hofn',
#  'amberley',
#  'ostersund',
#  'san-pedro',
#  'port lincoln',
#  'leningradskiy',
#  'mankono',
#  'eyl',
#  'san francisco',
#  'innisfail',
#  'camana',
#  'havelock',
#  'bulgan',
#  'novikovo',
#  'bukachacha',
#  'honningsvag',
#  'sychevka',
#  'aqtobe',
#  'dodge city',
#  'nokaneng',
#  'nola',
#  'norman wells',
#  'thabazimbi',
#  'southern pines',
#  'lavrentiya',
#  'vila',
#  'okhotsk',
#  'vila velha',
#  'poso',
#  'san carlos de bariloche',
#  'sao felix do xingu',
#  'begles',
#  'ajdabiya',
#  'kununurra',
#  'gejiu',
#  'ostrovnoy',
#  'andenes',
#  'tucuma',
#  'sorland',
#  'hit',
#  'ozgon',
#  'hamilton',
#  'kisangani',
#  'benjamin hill',
#  'hobyo',
#  'sayyan',
#  'yerbogachen',
#  'meru',
#  'coro',
#  'mount gambier',
#  'keetmanshoop',
#  'clarksburg',
#  'coquimbo',
#  'ihosy',
#  'vilhena',
#  'sundargarh',
#  'matay',
#  'puerto leguizamo',
#  'port blair',
#  'aasiaat',
#  'amderma',
#  'whitehorse',
#  'morehead',
#  'pacific grove',
#  'bargal',
#  'saint-francois',
#  'apt',
#  'tianpeng',
#  'visby',
#  'xuddur',
#  'chalmette',
#  'pisco',
#  'udachnyy',
#  'plettenberg bay',
#  'porto novo',
#  'hambantota',
#  'san rafael',
#  'dong hoi',
#  'edinburg',
#  'tual',
#  'sipe sipe',
#  'ondo',
#  'dori',
#  'bahia blanca',
#  'key largo',
#  'yumen',
#  'vigrestad',
#  'viligili',
#  'alamosa',
#  'gaoua',
#  'brae',
#  'le port',
#  'totness',
#  'sungaipenuh',
#  'burica',
#  'lasa',
#  'comrat',
#  'morant bay',
#  'sault sainte marie',
#  'reconquista',
#  'burlington',
#  'buin',
#  'alugan',
#  'panjab',
#  'tezu',
#  'solovetskiy',
#  'raga',
#  'athni',
#  'hvide sande',
#  'slave lake',
#  'teguldet',
#  'codrington',
#  'conop',
#  'tromso',
#  'skagastrond',
#  'maceio',
#  'wa',
#  'zapolyarnyy',
#  'takoradi',
#  'ponta do sol',
#  'axim',
#  'dhidhdhoo',
#  'kirkwall',
#  'acajutla',
#  'lagoa',
#  'forbes',
#  'bolungarvik',
#  'zhuhai',
#  'labytnangi',
#  'san dionisio',
#  'menongue',
#  'tautira',
#  'cayenne',
#  'cooma',
#  'hackettstown',
#  'portland',
#  'krapivinskiy',
#  'xining',
#  'kumluca',
#  'sterling',
#  'bengkulu',
#  'coihaique',
#  'los llanos de aridane',
#  'nemuro',
#  'labuhan',
#  'leh',
#  'altamira',
#  'fereydun kenar',
#  'beian',
#  'kruisfontein',
#  'mantua',
#  'luganville',
#  'petropavlovsk-kamchatskiy',
#  'agadir',
#  'kavaratti',
#  'doha',
#  'port hardy',
#  'margate',
#  'urumqi',
#  'hualmay',
#  'saint-georges',
#  'korla',
#  'las vegas',
#  'pauini',
#  'great yarmouth',
#  'juneau',
#  'suez',
#  'arman',
#  'asfi',
#  'anshun',
#  'mawlaik',
#  'segovia',
#  'turukhansk',
#  'nador',
#  'touros',
#  'la ronge',
#  'karibib',
#  'samarai',
#  'lompoc',
#  'mulege',
#  'nishihara',
#  'saint-pierre',
#  'lurgan',
#  'aykhal',
#  'ankang',
#  'natal',
#  'tallahassee',
#  'guiratinga',
#  'general roca',
#  'san pedro de cajas',
#  'bogorodskoye',
#  'kamenskoye',
#  'mandalgovi',
#  'cherskiy',
#  'quatis',
#  'roebourne',
#  'mehran',
#  'naftalan',
#  'monte carmelo',
#  'caravelas',
#  'concepcion del oro',
#  'port keats',
#  'kokoda',
#  'lobito',
#  'tura',
#  'price',
#  'bockenem',
#  'necochea',
#  'itarema',
#  'umred',
#  'bilibino',
#  'camacha',
#  'chimore',
#  'ballina',
#  'isla vista',
#  'cienfuegos',
#  'mecca',
#  'kalabo',
#  'langgons',
#  'san jeronimo',
#  'omsukchan',
#  'bereznehuvate',
#  'dzhankoy',
#  'along',
#  'oktyabrskoye',
#  'mundo nuevo',
#  'batticaloa',
#  'galle',
#  'taltal',
#  'moron',
#  'buchanan',
#  'kitale',
#  'mendi',
#  'kathmandu',
#  'chagda',
#  'najran',
#  'auki',
#  'makakilo city',
#  'mingoyo',
#  'nyrob',
#  'osypenko',
#  'saint george',
#  'lima',
#  'zhumadian',
#  'berdigestyakh',
#  'zhezkazgan',
#  'sakakah',
#  'gornopravdinsk',
#  'tomatlan',
#  'mergui',
#  'port augusta',
#  'sicamous',
#  'calamar',
#  'jangaon',
#  'matara',
#  'pajacuaran',
#  'tonj',
#  'mahibadhoo',
#  'airai',
#  'ketchikan',
#  'bubaque',
#  'cabo san lucas',
#  'jega',
#  'bumba',
#  'jardim',
#  'churapcha',
#  'cagayan de tawi-tawi',
#  'bloomfield',
#  'aksu',
#  'bara',
#  'jiujiang',
#  'jurbarkas',
#  'opuwo',
#  'ambanja',
#  'buala',
#  'luang prabang',
#  'santiago del estero',
#  'oksfjord',
#  'mutsamudu',
#  'bayji',
#  'fallon',
#  'kalevala',
#  'ampanihy',
#  'uray',
#  'morganton',
#  'ambovombe',
#  'mahajanga',
#  'tapaua',
#  'bur gabo',
#  'meadow lake',
#  'romny',
#  'tuy hoa',
#  'garissa',
#  'acarau',
#  'grand centre',
#  'dingle',
#  'batagay',
#  'kodinsk',
#  'neyshabur',
#  'staraya kulatka',
#  'sataua',
#  'huilong',
#  'rasra',
#  'charters towers',
#  'homer',
#  'mangai',
#  'joshimath',
#  'severo-yeniseyskiy',
#  'show low',
#  'zlatograd',
#  'bafoulabe',
#  'padang',
#  'srednekolymsk',
#  'havre-saint-pierre',
#  'kahului',
#  'shar',
#  'narsaq',
#  'formoso do araguaia',
#  'zolotkovo',
#  'cockburn harbour',
#  'liverpool',
#  'klenovyy',
#  'seymchan',
#  'milos',
#  'holesov',
#  'san andres',
#  'morondava',
#  'kyren',
#  'port hedland',
#  'tabiauea',
#  'amahai',
#  'namatanai',
#  'baker city',
#  'vestmannaeyjar',
#  'saint-augustin',
#  'halalo',
#  'alfatar',
#  'sikonge',
#  'jiwani',
#  'rundu',
#  'umm lajj',
#  'iskateley',
#  'san vicente',
#  'boguchany',
#  'muros',
#  'maraa',
#  'trincomalee',
#  'arlit',
#  'bassano del grappa',
#  'holme',
#  'phan thiet',
#  'tamazulapam',
#  'mangrol',
#  'broken hill',
#  'cairns',
#  'duluth']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Create count
count = 1

# starting statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:  
    

    try: 
        # used API respond from https://openweathermap.org/current
        response = requests.get(query_url + city).json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        cityname = response["name"]
        print(f"Processing Record {count} of Set {count} | {cityname}")
        
        # add 1 to count
        count = count + 1
    
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    
    
print(f"-------------------------------")     
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | Nikolskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 2 | Coos Bay
# Processing Record 3 of Set 3 | Katsuura
# City not found. Skipping...
# Processing Record 4 of Set 4 | Port Elizabeth
# Processing Record 5 of Set 5 | Geraldton
# Processing Record 6 of Set 6 | Thompson
# Processing Record 7 of Set 7 | Asnaes
# Processing Record 8 of Set 8 | Hilo
# City not found. Skipping...
# Processing Record 9 of Set 9 | Mayumba
# Processing Record 10 of Set 10 | Luanda
# Processing Record 11 of Set 11 | Aklavik
# City not found. Skipping...
# Processing Record 12 of Set 12 | Prince Rupert
# Processing Record 13 of Set 13 | Bluff
# Processing Record 14 of Set 14 | Namibe
# Processing Record 15 of Set 15 | Rikitea
# Processing Record 16 of Set 16 | Barrow
# Processing Record 17 of Set 17 | Jamestown
# Processing Record 18 of Set 18 | Nangomba
# Processing Record 19 of Set 19 | Souillac
# Processing Record 20 of Set 20 | Chokurdakh
# Processing Record 21 of Set 21 | Atuona
# Processing Record 22 of Set 22 | Nome
# Processing Record 23 of Set 23 | Kutum
# Processing Record 24 of Set 24 | Harper
# Processing Record 25 of Set 25 | Vao
# Processing Record 26 of Set 26 | Longyearbyen
# Processing Record 27 of Set 27 | Peto
# Processing Record 28 of Set 28 | Paamiut
# Processing Record 29 of Set 29 | Prainha
# Processing Record 30 of Set 30 | Hobart
# Processing Record 31 of Set 31 | Ahipara
# Processing Record 32 of Set 32 | Tuensang
# Processing Record 33 of Set 33 | Flin Flon
# City not found. Skipping...
# Processing Record 34 of Set 34 | Bargarh
# Processing Record 35 of Set 35 | Aransas Pass
# Processing Record 36 of Set 36 | Nogliki
# Processing Record 37 of Set 37 | Bredasdorp
# Processing Record 38 of Set 38 | Copiapo
# Processing Record 39 of Set 39 | Castro
# Processing Record 40 of Set 40 | San Lorenzo de El Escorial
# Processing Record 41 of Set 41 | Ulladulla
# Processing Record 42 of Set 42 | Ushuaia
# Processing Record 43 of Set 43 | Tiksi
# Processing Record 44 of Set 44 | Port Alfred
# Processing Record 45 of Set 45 | Saskylakh
# Processing Record 46 of Set 46 | Ardesen
# City not found. Skipping...
# Processing Record 47 of Set 47 | Saint-Philippe
# Processing Record 48 of Set 48 | Busselton
# Processing Record 49 of Set 49 | Khatanga
# Processing Record 50 of Set 50 | Punta Arenas
# Processing Record 51 of Set 51 | Visnes
# Processing Record 52 of Set 52 | Bethel
# Processing Record 53 of Set 53 | Jovellar
# Processing Record 54 of Set 54 | Tuktoyaktuk
# Processing Record 55 of Set 55 | Torbay
# Processing Record 56 of Set 56 | Tessalit
# Processing Record 57 of Set 57 | Dikson
# Processing Record 58 of Set 58 | Meulaboh
# Processing Record 59 of Set 59 | Belaya Gora
# Processing Record 60 of Set 60 | Mataura
# Processing Record 61 of Set 61 | Bayir
# Processing Record 62 of Set 62 | New Norfolk
# Processing Record 63 of Set 63 | Hithadhoo
# Processing Record 64 of Set 64 | Half Moon Bay
# Processing Record 65 of Set 65 | Ribeira Grande
# Processing Record 66 of Set 66 | Kudahuvadhoo
# Processing Record 67 of Set 67 | Dhadar
# Processing Record 68 of Set 68 | Kut Chap
# Processing Record 69 of Set 69 | Klaksvik
# Processing Record 70 of Set 70 | Albany
# Processing Record 71 of Set 71 | Provideniya
# Processing Record 72 of Set 72 | Sept-Iles
# City not found. Skipping...
# Processing Record 73 of Set 73 | Hienghene
# Processing Record 74 of Set 74 | Honiara
# Processing Record 75 of Set 75 | Ayr
# Processing Record 76 of Set 76 | Upernavik
# Processing Record 77 of Set 77 | Qaanaaq
# Processing Record 78 of Set 78 | Spydeberg
# Processing Record 79 of Set 79 | Beringovskiy
# Processing Record 80 of Set 80 | Ancud
# Processing Record 81 of Set 81 | Zhigansk
# Processing Record 82 of Set 82 | Adrar
# Processing Record 83 of Set 83 | Rabo de Peixe
# Processing Record 84 of Set 84 | Maniwaki
# Processing Record 85 of Set 85 | Avarua
# Processing Record 86 of Set 86 | Lebu
# Processing Record 87 of Set 87 | Kulhudhuffushi
# Processing Record 88 of Set 88 | Nantucket
# Processing Record 89 of Set 89 | Bonavista
# Processing Record 90 of Set 90 | Lokosovo
# Processing Record 91 of Set 91 | Saint-Tite
# Processing Record 92 of Set 92 | Sao Joao da Barra
# City not found. Skipping...
# Processing Record 93 of Set 93 | Pedernales
# Processing Record 94 of Set 94 | Mar del Plata
# Processing Record 95 of Set 95 | Fortuna
# Processing Record 96 of Set 96 | Puerto Ayora
# Processing Record 97 of Set 97 | Broome
# City not found. Skipping...
# Processing Record 98 of Set 98 | Inirida
# Processing Record 99 of Set 99 | Santa Isabel
# Processing Record 100 of Set 100 | Carauari
# Processing Record 101 of Set 101 | Christchurch
# Processing Record 102 of Set 102 | San Quintin
# City not found. Skipping...
# Processing Record 103 of Set 103 | Butaritari
# Processing Record 104 of Set 104 | Chimoio
# Processing Record 105 of Set 105 | Daru
# Processing Record 106 of Set 106 | Praia
# Processing Record 107 of Set 107 | Kaitangata
# Processing Record 108 of Set 108 | Georgetown
# Processing Record 109 of Set 109 | Mahebourg
# Processing Record 110 of Set 110 | Haines Junction
# Processing Record 111 of Set 111 | Cape Town
# Processing Record 112 of Set 112 | Cordoba
# Processing Record 113 of Set 113 | Lata
# Processing Record 114 of Set 114 | Pathein
# Processing Record 115 of Set 115 | Yakeshi
# Processing Record 116 of Set 116 | Leo
# City not found. Skipping...
# Processing Record 117 of Set 117 | Vardo
# Processing Record 118 of Set 118 | Yaan
# Processing Record 119 of Set 119 | Kloulklubed
# Processing Record 120 of Set 120 | Victoria
# Processing Record 121 of Set 121 | San Patricio
# City not found. Skipping...
# Processing Record 122 of Set 122 | Tondon
# Processing Record 123 of Set 123 | Oktyabrskiy
# Processing Record 124 of Set 124 | Yongchang
# Processing Record 125 of Set 125 | Faanui
# Processing Record 126 of Set 126 | Gorontalo
# Processing Record 127 of Set 127 | Arraial do Cabo
# Processing Record 128 of Set 128 | East London
# Processing Record 129 of Set 129 | Saint-Joseph
# Processing Record 130 of Set 130 | Clyde River
# Processing Record 131 of Set 131 | Mastic Beach
# City not found. Skipping...
# Processing Record 132 of Set 132 | Alofi
# Processing Record 133 of Set 133 | Tokur
# Processing Record 134 of Set 134 | Carnarvon
# Processing Record 135 of Set 135 | Cidreira
# Processing Record 136 of Set 136 | Bandarbeyla
# Processing Record 137 of Set 137 | Puyang
# City not found. Skipping...
# Processing Record 138 of Set 138 | Pevek
# Processing Record 139 of Set 139 | Iquitos
# Processing Record 140 of Set 140 | Keti Bandar
# City not found. Skipping...
# Processing Record 141 of Set 141 | Luderitz
# Processing Record 142 of Set 142 | Vaini
# Processing Record 143 of Set 143 | Te Anau
# City not found. Skipping...
# Processing Record 144 of Set 144 | Severo-Kurilsk
# Processing Record 145 of Set 145 | Sioux Lookout
# Processing Record 146 of Set 146 | Nhulunbuy
# Processing Record 147 of Set 147 | Marzuq
# Processing Record 148 of Set 148 | Da Lat
# Processing Record 149 of Set 149 | Sroda Wielkopolska
# Processing Record 150 of Set 150 | Fonte Boa
# Processing Record 151 of Set 151 | Puerto Narino
# Processing Record 152 of Set 152 | Kroya
# Processing Record 153 of Set 153 | Kodiak
# Processing Record 154 of Set 154 | Vila Franca do Campo
# Processing Record 155 of Set 155 | Kavieng
# Processing Record 156 of Set 156 | Bonito
# Processing Record 157 of Set 157 | Barra do Garcas
# Processing Record 158 of Set 158 | Sao Filipe
# Processing Record 159 of Set 159 | Berlevag
# City not found. Skipping...
# Processing Record 160 of Set 160 | Kapaa
# Processing Record 161 of Set 161 | Saint Lawrence
# Processing Record 162 of Set 162 | Puerto Escondido
# Processing Record 163 of Set 163 | Hun
# Processing Record 164 of Set 164 | Assiniboia
# Processing Record 165 of Set 165 | Micheweni
# City not found. Skipping...
# Processing Record 166 of Set 166 | Lodingen
# Processing Record 167 of Set 167 | Awjilah
# Processing Record 168 of Set 168 | Constitucion
# Processing Record 169 of Set 169 | Batagay-Alyta
# Processing Record 170 of Set 170 | Mackenzie
# Processing Record 171 of Set 171 | Piacabucu
# Processing Record 172 of Set 172 | Acaponeta
# Processing Record 173 of Set 173 | Mezen
# Processing Record 174 of Set 174 | Komsomolskiy
# Processing Record 175 of Set 175 | Iberia
# City not found. Skipping...
# Processing Record 176 of Set 176 | Dunedin
# Processing Record 177 of Set 177 | Khandyga
# Processing Record 178 of Set 178 | Sobolevo
# Processing Record 179 of Set 179 | Hermanus
# Processing Record 180 of Set 180 | Laguna
# Processing Record 181 of Set 181 | Simao
# Processing Record 182 of Set 182 | Balintore
# City not found. Skipping...
# Processing Record 183 of Set 183 | Belyy Yar
# Processing Record 184 of Set 184 | Akureyri
# Processing Record 185 of Set 185 | Tuatapere
# City not found. Skipping...
# Processing Record 186 of Set 186 | Hasaki
# Processing Record 187 of Set 187 | Vostok
# Processing Record 188 of Set 188 | Comodoro Rivadavia
# Processing Record 189 of Set 189 | Palmer
# City not found. Skipping...
# Processing Record 190 of Set 190 | Baykit
# Processing Record 191 of Set 191 | Ewa Beach
# Processing Record 192 of Set 192 | Poum
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 193 of Set 193 | Dalbandin
# City not found. Skipping...
# Processing Record 194 of Set 194 | Shingu
# Processing Record 195 of Set 195 | Maragogi
# Processing Record 196 of Set 196 | Kampong Chhnang
# Processing Record 197 of Set 197 | Faya
# Processing Record 198 of Set 198 | Bukama
# Processing Record 199 of Set 199 | Saldanha
# City not found. Skipping...
# Processing Record 200 of Set 200 | Nuuk
# Processing Record 201 of Set 201 | Yellowknife
# Processing Record 202 of Set 202 | Bambous Virieux
# Processing Record 203 of Set 203 | Mitzic
# Processing Record 204 of Set 204 | Det Udom
# Processing Record 205 of Set 205 | Quatre Cocos
# Processing Record 206 of Set 206 | Kirakira
# Processing Record 207 of Set 207 | Flinders
# City not found. Skipping...
# Processing Record 208 of Set 208 | Staryy Nadym
# Processing Record 209 of Set 209 | Esperance
# City not found. Skipping...
# Processing Record 210 of Set 210 | Araouane
# Processing Record 211 of Set 211 | Pearl Lagoon
# Processing Record 212 of Set 212 | Ngong
# Processing Record 213 of Set 213 | Praia da Vitoria
# Processing Record 214 of Set 214 | Abu Samrah
# Processing Record 215 of Set 215 | Tiznit
# Processing Record 216 of Set 216 | Salalah
# Processing Record 217 of Set 217 | Quiruvilca
# Processing Record 218 of Set 218 | Jacareacanga
# Processing Record 219 of Set 219 | Naryan-Mar
# Processing Record 220 of Set 220 | Niquero
# Processing Record 221 of Set 221 | Muisne
# Processing Record 222 of Set 222 | Tasiilaq
# Processing Record 223 of Set 223 | Nanortalik
# Processing Record 224 of Set 224 | Usinsk
# Processing Record 225 of Set 225 | Artesia
# City not found. Skipping...
# Processing Record 226 of Set 226 | Port Macquarie
# Processing Record 227 of Set 227 | Chenghai
# City not found. Skipping...
# Processing Record 228 of Set 228 | Talnakh
# Processing Record 229 of Set 229 | Palotina
# Processing Record 230 of Set 230 | Birin
# Processing Record 231 of Set 231 | Ilulissat
# Processing Record 232 of Set 232 | La Mana
# City not found. Skipping...
# Processing Record 233 of Set 233 | Kenai
# Processing Record 234 of Set 234 | Ugoofaaru
# Processing Record 235 of Set 235 | Bilecik
# City not found. Skipping...
# Processing Record 236 of Set 236 | Zyryanka
# Processing Record 237 of Set 237 | Kandrian
# Processing Record 238 of Set 238 | Avera
# Processing Record 239 of Set 239 | Chuy
# Processing Record 240 of Set 240 | Gat
# Processing Record 241 of Set 241 | Lewisporte
# Processing Record 242 of Set 242 | Estevan
# Processing Record 243 of Set 243 | Westport
# Processing Record 244 of Set 244 | Hofn
# Processing Record 245 of Set 245 | Amberley
# Processing Record 246 of Set 246 | Ostersund
# Processing Record 247 of Set 247 | San-Pedro
# Processing Record 248 of Set 248 | Port Lincoln
# Processing Record 249 of Set 249 | Leningradskiy
# Processing Record 250 of Set 250 | Mankono
# Processing Record 251 of Set 251 | Eyl
# Processing Record 252 of Set 252 | San Francisco
# Processing Record 253 of Set 253 | Innisfail
# City not found. Skipping...
# Processing Record 254 of Set 254 | Havelock
# Processing Record 255 of Set 255 | Bulgan
# Processing Record 256 of Set 256 | Novikovo
# Processing Record 257 of Set 257 | Bukachacha
# Processing Record 258 of Set 258 | Honningsvag
# Processing Record 259 of Set 259 | Sychevka
# Processing Record 260 of Set 260 | Aqtobe
# Processing Record 261 of Set 261 | Dodge City
# Processing Record 262 of Set 262 | Nokaneng
# Processing Record 263 of Set 263 | Nola
# Processing Record 264 of Set 264 | Norman Wells
# Processing Record 265 of Set 265 | Thabazimbi
# Processing Record 266 of Set 266 | Southern Pines
# Processing Record 267 of Set 267 | Lavrentiya
# Processing Record 268 of Set 268 | Vila
# Processing Record 269 of Set 269 | Okhotsk
# Processing Record 270 of Set 270 | Vila Velha
# Processing Record 271 of Set 271 | Poso
# Processing Record 272 of Set 272 | San Carlos de Bariloche
# Processing Record 273 of Set 273 | Sao Felix do Xingu
# Processing Record 274 of Set 274 | Begles
# Processing Record 275 of Set 275 | Ajdabiya
# Processing Record 276 of Set 276 | Kununurra
# Processing Record 277 of Set 277 | Gejiu
# Processing Record 278 of Set 278 | Ostrovnoy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 279 of Set 279 | Sorland
# Processing Record 280 of Set 280 | Hit
# City not found. Skipping...
# Processing Record 281 of Set 281 | Hamilton
# Processing Record 282 of Set 282 | Kisangani
# Processing Record 283 of Set 283 | Benjamin Hill
# Processing Record 284 of Set 284 | Hobyo
# Processing Record 285 of Set 285 | Sayyan
# Processing Record 286 of Set 286 | Yerbogachen
# Processing Record 287 of Set 287 | Meru
# Processing Record 288 of Set 288 | Coro
# Processing Record 289 of Set 289 | Mount Gambier
# Processing Record 290 of Set 290 | Keetmanshoop
# Processing Record 291 of Set 291 | Clarksburg
# Processing Record 292 of Set 292 | Coquimbo
# Processing Record 293 of Set 293 | Ihosy
# Processing Record 294 of Set 294 | Vilhena
# Processing Record 295 of Set 295 | Sundargarh
# Processing Record 296 of Set 296 | Matay
# Processing Record 297 of Set 297 | Puerto Leguizamo
# Processing Record 298 of Set 298 | Port Blair
# Processing Record 299 of Set 299 | Aasiaat
# City not found. Skipping...
# Processing Record 300 of Set 300 | Whitehorse
# Processing Record 301 of Set 301 | Morehead
# Processing Record 302 of Set 302 | Pacific Grove
# City not found. Skipping...
# Processing Record 303 of Set 303 | Saint-Francois
# Processing Record 304 of Set 304 | Apt
# Processing Record 305 of Set 305 | Tianpeng
# Processing Record 306 of Set 306 | Visby
# Processing Record 307 of Set 307 | Xuddur
# Processing Record 308 of Set 308 | Chalmette
# Processing Record 309 of Set 309 | Pisco
# Processing Record 310 of Set 310 | Udachnyy
# Processing Record 311 of Set 311 | Plettenberg Bay
# Processing Record 312 of Set 312 | Porto Novo
# Processing Record 313 of Set 313 | Hambantota
# Processing Record 314 of Set 314 | San Rafael
# Processing Record 315 of Set 315 | Dong Hoi
# Processing Record 316 of Set 316 | Edinburg
# Processing Record 317 of Set 317 | Tual
# Processing Record 318 of Set 318 | Sipe Sipe
# Processing Record 319 of Set 319 | Ondo
# Processing Record 320 of Set 320 | Dori
# Processing Record 321 of Set 321 | Bahia Blanca
# Processing Record 322 of Set 322 | Key Largo
# Processing Record 323 of Set 323 | Yumen
# Processing Record 324 of Set 324 | Vigrestad
# City not found. Skipping...
# Processing Record 325 of Set 325 | Alamosa
# Processing Record 326 of Set 326 | Gaoua
# Processing Record 327 of Set 327 | Brae
# Processing Record 328 of Set 328 | Le Port
# Processing Record 329 of Set 329 | Totness
# Processing Record 330 of Set 330 | Sungaipenuh
# City not found. Skipping...
# Processing Record 331 of Set 331 | Lasa
# Processing Record 332 of Set 332 | Comrat
# Processing Record 333 of Set 333 | Morant Bay
# Processing Record 334 of Set 334 | Sault Sainte Marie
# Processing Record 335 of Set 335 | Reconquista
# Processing Record 336 of Set 336 | Burlington
# Processing Record 337 of Set 337 | Buin
# Processing Record 338 of Set 338 | Alugan
# Processing Record 339 of Set 339 | Panjab
# Processing Record 340 of Set 340 | Tezu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 341 of Set 341 | Athni
# Processing Record 342 of Set 342 | Hvide Sande
# Processing Record 343 of Set 343 | Slave Lake
# Processing Record 344 of Set 344 | Teguldet
# Processing Record 345 of Set 345 | Codrington
# Processing Record 346 of Set 346 | Conop
# Processing Record 347 of Set 347 | Tromso
# City not found. Skipping...
# Processing Record 348 of Set 348 | Maceio
# City not found. Skipping...
# Processing Record 349 of Set 349 | Zapolyarnyy
# Processing Record 350 of Set 350 | Takoradi
# Processing Record 351 of Set 351 | Ponta do Sol
# Processing Record 352 of Set 352 | Axim
# Processing Record 353 of Set 353 | Dhidhdhoo
# Processing Record 354 of Set 354 | Kirkwall
# Processing Record 355 of Set 355 | Acajutla
# Processing Record 356 of Set 356 | Lagoa
# Processing Record 357 of Set 357 | Forbes
# City not found. Skipping...
# Processing Record 358 of Set 358 | Zhuhai
# Processing Record 359 of Set 359 | Labytnangi
# Processing Record 360 of Set 360 | San Dionisio
# Processing Record 361 of Set 361 | Menongue
# Processing Record 362 of Set 362 | Tautira
# Processing Record 363 of Set 363 | Cayenne
# Processing Record 364 of Set 364 | Cooma
# Processing Record 365 of Set 365 | Hackettstown
# Processing Record 366 of Set 366 | Portland
# Processing Record 367 of Set 367 | Krapivinskiy
# Processing Record 368 of Set 368 | Xining
# Processing Record 369 of Set 369 | Kumluca
# Processing Record 370 of Set 370 | Sterling
# City not found. Skipping...
# Processing Record 371 of Set 371 | Coihaique
# Processing Record 372 of Set 372 | Los Llanos de Aridane
# Processing Record 373 of Set 373 | Nemuro
# Processing Record 374 of Set 374 | Labuhan
# Processing Record 375 of Set 375 | Leh
# Processing Record 376 of Set 376 | Altamira
# Processing Record 377 of Set 377 | Fereydun Kenar
# Processing Record 378 of Set 378 | Beian
# Processing Record 379 of Set 379 | Kruisfontein
# Processing Record 380 of Set 380 | Mantua
# Processing Record 381 of Set 381 | Luganville
# Processing Record 382 of Set 382 | Petropavlovsk-Kamchatskiy
# Processing Record 383 of Set 383 | Agadir
# Processing Record 384 of Set 384 | Kavaratti
# Processing Record 385 of Set 385 | Doha
# Processing Record 386 of Set 386 | Port Hardy
# Processing Record 387 of Set 387 | Margate
# City not found. Skipping...
# Processing Record 388 of Set 388 | Hualmay
# Processing Record 389 of Set 389 | Saint-Georges
# City not found. Skipping...
# Processing Record 390 of Set 390 | Las Vegas
# Processing Record 391 of Set 391 | Pauini
# Processing Record 392 of Set 392 | Great Yarmouth
# Processing Record 393 of Set 393 | Juneau
# Processing Record 394 of Set 394 | Suez
# Processing Record 395 of Set 395 | Arman
# City not found. Skipping...
# Processing Record 396 of Set 396 | Anshun
# Processing Record 397 of Set 397 | Mawlaik
# Processing Record 398 of Set 398 | Segovia
# Processing Record 399 of Set 399 | Turukhansk
# Processing Record 400 of Set 400 | Nador
# Processing Record 401 of Set 401 | Touros
# Processing Record 402 of Set 402 | La Ronge
# Processing Record 403 of Set 403 | Karibib
# Processing Record 404 of Set 404 | Samarai
# Processing Record 405 of Set 405 | Lompoc
# Processing Record 406 of Set 406 | Mulege
# Processing Record 407 of Set 407 | Nishihara
# Processing Record 408 of Set 408 | Saint-Pierre
# Processing Record 409 of Set 409 | Lurgan
# Processing Record 410 of Set 410 | Aykhal
# Processing Record 411 of Set 411 | Ankang
# Processing Record 412 of Set 412 | Natal
# Processing Record 413 of Set 413 | Tallahassee
# Processing Record 414 of Set 414 | Guiratinga
# Processing Record 415 of Set 415 | General Roca
# Processing Record 416 of Set 416 | San Pedro de Cajas
# Processing Record 417 of Set 417 | Bogorodskoye
# City not found. Skipping...
# Processing Record 418 of Set 418 | Mandalgovi
# Processing Record 419 of Set 419 | Cherskiy
# Processing Record 420 of Set 420 | Quatis
# Processing Record 421 of Set 421 | Roebourne
# Processing Record 422 of Set 422 | Mehran
# Processing Record 423 of Set 423 | Naftalan
# Processing Record 424 of Set 424 | Monte Carmelo
# Processing Record 425 of Set 425 | Caravelas
# Processing Record 426 of Set 426 | Concepcion del Oro
# Processing Record 427 of Set 427 | Port Keats
# Processing Record 428 of Set 428 | Kokoda
# Processing Record 429 of Set 429 | Lobito
# Processing Record 430 of Set 430 | Tura
# Processing Record 431 of Set 431 | Price
# Processing Record 432 of Set 432 | Bockenem
# Processing Record 433 of Set 433 | Necochea
# Processing Record 434 of Set 434 | Itarema
# Processing Record 435 of Set 435 | Umred
# Processing Record 436 of Set 436 | Bilibino
# Processing Record 437 of Set 437 | Camacha
# Processing Record 438 of Set 438 | Chimore
# Processing Record 439 of Set 439 | Ballina
# Processing Record 440 of Set 440 | Isla Vista
# Processing Record 441 of Set 441 | Cienfuegos
# Processing Record 442 of Set 442 | Mecca
# Processing Record 443 of Set 443 | Kalabo
# Processing Record 444 of Set 444 | Langgons
# Processing Record 445 of Set 445 | San Jeronimo
# Processing Record 446 of Set 446 | Omsukchan
# Processing Record 447 of Set 447 | Bereznehuvate
# Processing Record 448 of Set 448 | Dzhankoy
# Processing Record 449 of Set 449 | Along
# Processing Record 450 of Set 450 | Oktyabrskoye
# Processing Record 451 of Set 451 | Mundo Nuevo
# Processing Record 452 of Set 452 | Batticaloa
# Processing Record 453 of Set 453 | Galle
# Processing Record 454 of Set 454 | Taltal
# Processing Record 455 of Set 455 | Moron
# Processing Record 456 of Set 456 | Buchanan
# Processing Record 457 of Set 457 | Kitale
# Processing Record 458 of Set 458 | Mendi
# Processing Record 459 of Set 459 | Kathmandu
# City not found. Skipping...
# Processing Record 460 of Set 460 | Najran
# Processing Record 461 of Set 461 | Auki
# Processing Record 462 of Set 462 | Makakilo City
# Processing Record 463 of Set 463 | Mingoyo
# Processing Record 464 of Set 464 | Nyrob
# Processing Record 465 of Set 465 | Osypenko
# Processing Record 466 of Set 466 | Saint George
# Processing Record 467 of Set 467 | Lima
# Processing Record 468 of Set 468 | Zhumadian
# Processing Record 469 of Set 469 | Berdigestyakh
# Processing Record 470 of Set 470 | Zhezkazgan
# City not found. Skipping...
# Processing Record 471 of Set 471 | Gornopravdinsk
# Processing Record 472 of Set 472 | Tomatlan
# City not found. Skipping...
# Processing Record 473 of Set 473 | Port Augusta
# Processing Record 474 of Set 474 | Sicamous
# Processing Record 475 of Set 475 | Calamar
# Processing Record 476 of Set 476 | Jangaon
# Processing Record 477 of Set 477 | Matara
# Processing Record 478 of Set 478 | Pajacuaran
# City not found. Skipping...
# Processing Record 479 of Set 479 | Mahibadhoo
# Processing Record 480 of Set 480 | Airai
# Processing Record 481 of Set 481 | Ketchikan
# Processing Record 482 of Set 482 | Bubaque
# Processing Record 483 of Set 483 | Cabo San Lucas
# Processing Record 484 of Set 484 | Jega
# Processing Record 485 of Set 485 | Bumba
# Processing Record 486 of Set 486 | Jardim
# Processing Record 487 of Set 487 | Churapcha
# City not found. Skipping...
# Processing Record 488 of Set 488 | Bloomfield
# Processing Record 489 of Set 489 | Aksu
# Processing Record 490 of Set 490 | Bara
# Processing Record 491 of Set 491 | Jiujiang
# Processing Record 492 of Set 492 | Jurbarkas
# Processing Record 493 of Set 493 | Opuwo
# Processing Record 494 of Set 494 | Ambanja
# Processing Record 495 of Set 495 | Buala
# Processing Record 496 of Set 496 | Luang Prabang
# Processing Record 497 of Set 497 | Santiago del Estero
# Processing Record 498 of Set 498 | Oksfjord
# City not found. Skipping...
# Processing Record 499 of Set 499 | Bayji
# Processing Record 500 of Set 500 | Fallon
# Processing Record 501 of Set 501 | Kalevala
# Processing Record 502 of Set 502 | Ampanihy
# Processing Record 503 of Set 503 | Uray
# Processing Record 504 of Set 504 | Morganton
# Processing Record 505 of Set 505 | Ambovombe
# Processing Record 506 of Set 506 | Mahajanga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 507 of Set 507 | Meadow Lake
# Processing Record 508 of Set 508 | Romny
# Processing Record 509 of Set 509 | Tuy Hoa
# Processing Record 510 of Set 510 | Garissa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 511 of Set 511 | Dingle
# Processing Record 512 of Set 512 | Batagay
# Processing Record 513 of Set 513 | Kodinsk
# Processing Record 514 of Set 514 | Neyshabur
# Processing Record 515 of Set 515 | Staraya Kulatka
# City not found. Skipping...
# Processing Record 516 of Set 516 | Huilong
# Processing Record 517 of Set 517 | Rasra
# Processing Record 518 of Set 518 | Charters Towers
# Processing Record 519 of Set 519 | Homer
# Processing Record 520 of Set 520 | Mangai
# Processing Record 521 of Set 521 | Joshimath
# Processing Record 522 of Set 522 | Severo-Yeniseyskiy
# Processing Record 523 of Set 523 | Show Low
# Processing Record 524 of Set 524 | Zlatograd
# Processing Record 525 of Set 525 | Bafoulabe
# Processing Record 526 of Set 526 | Padang
# Processing Record 527 of Set 527 | Srednekolymsk
# Processing Record 528 of Set 528 | Havre-Saint-Pierre
# Processing Record 529 of Set 529 | Kahului
# Processing Record 530 of Set 530 | Shar
# Processing Record 531 of Set 531 | Narsaq
# City not found. Skipping...
# Processing Record 532 of Set 532 | Zolotkovo
# City not found. Skipping...
# Processing Record 533 of Set 533 | Liverpool
# Processing Record 534 of Set 534 | Klenovyy
# Processing Record 535 of Set 535 | Seymchan
# Processing Record 536 of Set 536 | Milos
# Processing Record 537 of Set 537 | Holesov
# Processing Record 538 of Set 538 | San Andres
# Processing Record 539 of Set 539 | Morondava
# Processing Record 540 of Set 540 | Kyren
# Processing Record 541 of Set 541 | Port Hedland
# City not found. Skipping...
# Processing Record 542 of Set 542 | Amahai
# Processing Record 543 of Set 543 | Namatanai
# Processing Record 544 of Set 544 | Baker City
# Processing Record 545 of Set 545 | Vestmannaeyjar
# Processing Record 546 of Set 546 | Saint-Augustin
# City not found. Skipping...
# Processing Record 547 of Set 547 | Alfatar
# Processing Record 548 of Set 548 | Sikonge
# Processing Record 549 of Set 549 | Jiwani
# Processing Record 550 of Set 550 | Rundu
# Processing Record 551 of Set 551 | Umm Lajj
# Processing Record 552 of Set 552 | Iskateley
# Processing Record 553 of Set 553 | San Vicente
# Processing Record 554 of Set 554 | Boguchany
# Processing Record 555 of Set 555 | Muros
# Processing Record 556 of Set 556 | Maraa
# Processing Record 557 of Set 557 | Trincomalee
# Processing Record 558 of Set 558 | Arlit
# Processing Record 559 of Set 559 | Bassano del Grappa
# Processing Record 560 of Set 560 | Holme
# Processing Record 561 of Set 561 | Phan Thiet
# City not found. Skipping...
# Processing Record 562 of Set 562 | Mangrol
# Processing Record 563 of Set 563 | Broken Hill
# Processing Record 564 of Set 564 | Cairns
# Processing Record 565 of Set 565 | Duluth
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# dictionary
weather = {"City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed}

# Create dataframe 
city_data = pd.DataFrame(weather)

# Display dataframe 
city_data.count()
# Out:
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Lat           565
# Lng           565
# Max Temp      565
# Wind Speed    565
# dtype: int64

# %%
city_data.to_csv('cities.csv')

# %%
city_data.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Nikolskoye           0      RU  1561829603        59  59.70   30.79
# 1        Coos Bay          20      US  1561829782        77  43.37 -124.22
# 2        Katsuura          75      JP  1561829623        94  33.93  134.50
# 3  Port Elizabeth           1      US  1561829603        52  39.31  -74.98
# 4       Geraldton          40      CA  1561829622        49  49.72  -86.95
#
#    Max Temp  Wind Speed
# 0      62.6       11.18
# 1      64.0        4.41
# 2      75.2        2.24
# 3      95.0        9.17
# 4      69.8        9.17

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Temperature_Plot.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Humidity_Plot.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Cloudiness_Plot.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Wind Speed_Plot.png")

# Show plot
plt.show()
